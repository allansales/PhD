# %%
import requests

url = "http://api.meaningcloud.com/sentiment-2.1"

payload = "key=077d73ac19ed9c57be0e1f96bcf33ef3&lang=pt&txt='e ai que o barraco desabou'&model=YOUR_MODEL_VALUE"
headers = {'content-type': 'application/x-www-form-urlencoded'}

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"status":{"code":"201","msg":"Model not supported","credits":"0","remaining_credits":"40000"}}

# %%
from textblob import TextBlob

import pymongo

import pandas as pd
import numpy as np

from pymongo import MongoClient

import requests

# %%
client = MongoClient()
db = client.stocks
collection = db.tempNoticias
data = pd.DataFrame(list(collection.find()))
data
# Out:
#                          _id  \
# 0   594986390c0a0f66f9233bc6
# 1   5949863a0c0a0f66f9233bce
# 2   5949863b0c0a0f66f9233bcf
# 3   594986490c0a0f66f9233bd0
# 4   5949864c0c0a0f66f9233bd9
# 5   5949864c0c0a0f66f9233c04
# 6   5949864d0c0a0f66f9233c0e
# 7   5949864e0c0a0f66f9233c0f
# 8   5949864f0c0a0f66f9233c10
# 9   594986500c0a0f66f9233c11
# 10  594986580c0a0f66f9233c21
# 11  594986580c0a0f66f9233c22
# 12  594986590c0a0f66f9233c29
# 13  5949865a0c0a0f66f9233c2a
# 14  5949865b0c0a0f66f9233c2b
# 15  5949865c0c0a0f66f9233c2f
# 16  5949865d0c0a0f66f9233c30
# 17  594986610c0a0f66f9233c32
# 18  594986630c0a0f66f9233c34
# 19  594986640c0a0f66f9233c49
# 20  594986660c0a0f66f9233c4a
# 21  594986670c0a0f66f9233c52
# 22  594986680c0a0f66f9233c82
# 23  594986690c0a0f66f9233c83
# 24  5949866a0c0a0f66f9233c95
# 25  5949866a0c0a0f66f9233c96
# 26  5949866c0c0a0f66f9233c97
# 27  5949866d0c0a0f66f9233c98
# 28  5949866e0c0a0f66f9233c9c
# 29  5949866f0c0a0f66f9233cef
# 30  594986940c0a7815dcf91df8
# ...

# %%
conteudo = data.titulo

# %%
# Out:
# 0    Bastidores: Em cafezinho, ministros do STF e J...
# 1    Convocação de Temer pela PF é legítima, dizem ...
# 2                      Temer convoca Exército: entenda
# 3    Governo do DF diz que foi 'surpreendido' por u...
# 4          Oito candidatos concorrem ao cargo de Janot
# 5    O “Fora Temer”, a guerrilha urbana e os limite...
# 6       Maia cobra de Jungmann 'verdade' sobre decreto
# 7    Primeiro delator da Lava Jato confirma cartel ...
# 8    'Temer perdeu as condições de governabilidade'...
# 9    Jungmann: ‘A provocação partiu dos manifestantes’
# Name: titulo, dtype: object

# %%
from googletrans import Translator

translator = Translator()
translations = translator.translate(conteudo.iloc[:0], dest='en')
for translation in translations:
    print(translation.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-c308f6458f49> in <module>()
#       2
#       3 translator = Translator()
# ----> 4 translations = translator.translate(conteudo.iloc[:0], dest='en')
#       5 for translation in translations:
#       6     print(translation.text)
#
# /home/allan/anaconda2/lib/python2.7/site-packages/googletrans/client.pyc in translate(self, text, dest, src)
#     140         if not PY3 and isinstance(pron, unicode) and isinstance(origin, str):  # pragma: nocover
#     141             origin = origin.decode('utf-8')
# --> 142         if dest in EXCLUDES and pron == origin:
#     143             pron = translated
#     144
#
# /home/allan/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     890         raise ValueError("The truth value of a {0} is ambiguous. "
# ...
